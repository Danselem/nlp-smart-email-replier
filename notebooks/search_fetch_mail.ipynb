# %% [markdown]
# # Fetch Mails from Gmail using Gmail-API
#
# This is a project to search a gmail account, fetch the message content and return it into a nicely readable text.

# %%
#Importing required modules
from __future__ import print_function
import httplib2
import os
from googleapiclient.discovery import build
#from apiclient import discovery
from oauth2client import client
from oauth2client import tools
from oauth2client.file import Storage
import base64
from bs4 import BeautifulSoup
import re
import time
import dateutil.parser as parser
from datetime import datetime
import datetime
import email
from cleantext import clean
import csv
import pandas as pd


try:
    import argparse
    flags = argparse.ArgumentParser(parents=[tools.argparser]).parse_args([])
except ImportError:
    flags = None

# %%
#Defining auhorization scopes
SCOPES = 'https://www.googleapis.com/auth/gmail.readonly'
CLIENT_SECRET_FILE = 'credentials.json' #Name of gmail credential file
storage = 'gmail-storage.json' #Name of storage credential retured by Gmail API
APPLICATION_NAME = 'Gmail API Python' #Name of Application

#Function to activate credential
def get_credentials():
    """Gets valid user credentials from storage.

    If nothing has been stored, or if the stored credentials are invalid,
    the OAuth2 flow is completed to obtain the new credentials.

    Returns:
        Credentials, the obtained credential.
    """
    path = '~/Desktop/Doing_DS' #creating credential path
    home_dir = os.path.expanduser(path)
    credential_dir = os.path.join(home_dir, 'secrets')
    credential_path = os.path.join(credential_dir,
                                   CLIENT_SECRET_FILE)
    if not os.path.exists(credential_dir):
        os.makedirs(credential_dir)
    storage_path = os.path.join(credential_dir,
                                   storage)

    store = Storage(storage_path)
    credentials = store.get()
    if not credentials or credentials.invalid:
        flow = client.flow_from_clientsecrets(credential_path, SCOPES)
        flow.user_agent = APPLICATION_NAME
        if flags:
            credentials = tools.run_flow(flow, store, flags)
        else: # Needed only for compatibility with Python 2.6
            credentials = tools.run(flow, store)
        print('Storing credentials to ' + storage_path)
    return credentials

# %%
#getting credentials
credentials = get_credentials()

# %%
#A function to get authorization and create a service
def get_service():
    
    #authorization of credentials
    http = credentials.authorize(httplib2.Http())

    #service variable is the access point to complete gmail API
    service = build('gmail', 'v1', http=http)
    
    return service

# %%
#creating the service
service = get_service()

# %% [markdown]
# ## Searching Gmail to fetch mail id
# A search query is defined based on gmail search operator defined at https://support.google.com/mail/answer/7190?hl=en.
#
# A search query string is provided below as an example.

# %%
search_query = "yalin.mailer@state.gov, after:01/01/2020" 

def filter_mail(service, query):
    '''
    service = a gmail service
    
    query = a search query
    '''
    
    mail_id = service.users().messages().list(userId='me', 
                                              #maxResults=10,
                                              q=search_query).execute()['messages']

    return mail_id

# %%
mail_ids = filter_mail(service, query = search_query)

# %%
def data_encoder(text):
    if len(text)>0:
        message = base64.urlsafe_b64decode(text)
        message = str(message, 'utf-8')
        message = email.message_from_string(message)
    return message

# %%
def readMessage(content)->str:
    message = None
    if "data" in content['payload']['body']:
        message = content['payload']['body']['data']
        message = data_encoder(message)
    elif "data" in content['payload']['parts'][0]['body']:
        message = content['payload']['parts'][0]['body']['data']
        message = data_encoder(message)
    else:
        print("body has no data.")
    return message

# %%
def fetch_mail(mail_id):
    mail_list = []
    
    for ml_id in mail_id:
        mail_dict = { }
        m_id = ml_id['id'] # get id of individual message
        message = service.users().messages().get(userId= 'me',
                                                 id=m_id).execute() 
        payld = message['payload'] # get payload of the message 
        m_head = payld['headers'] # getting message payload header

        
        for sub in m_head: #Fetching the mail Subject
            if sub['name'] == 'Subject':
                m_subj = sub['value']
                mail_dict['Subject'] = m_subj
            else:
                pass
        
        
        for dt in m_head: # getting the date
            if dt['name'] == 'Date':
                mail_date = dt['value']
                date_parse = (parser.parse(mail_date))
                m_date = (date_parse.date())
                mail_dict['Date'] = str(m_date)
            else:
                pass

        
        for sender in m_head: # getting the Sender
            if sender['name'] == 'From':
                m_from = sender['value']
                mail_dict['Sender'] = m_from
            else:
                pass
            
        
            
        mssg = readMessage(message)
        msg_body = BeautifulSoup(mssg.get_payload(), 'lxml')
        msg_text = msg_body.body.get_text()
        clean_text = clean(msg_text, 
                           fix_unicode=True,
                           to_ascii=True,
                           lower = False,
                           no_line_breaks=True,
                           no_urls=True) # Execute all cleaning operations

        mail_dict['Message body'] = clean_text
        
        
        mail_list.append(mail_dict)
    
    return mail_list

# %%
mail_List = fetch_mail(mail_id = mail_ids)

# %%
def save_data(mail_list, file_path):
    with open(file_path, 'w', encoding='utf-8', newline = '') as csvfile: 
        #fieldnames = ['Sender','Subject','Date','Snippet','Message_body']
        fieldnames = ['Sender','Subject','Date','Message body']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter = ',')
        writer.writeheader()
        for val in mail_list:
            writer.writerow(val)

# %%
# file paths
raw_data_path = os.path.join(os.path.pardir,'src', 'data','raw')
fetchmail_data_path = os.path.join(raw_data_path, 'fetched_gmail.csv')

# %%
# save data
save_data(mail_List,fetchmail_data_path)

# %%
df = pd.read_csv(fetchmail_data_path)

# %%
df
# Out:
#                                    Sender  \
# 0   YALI Network <yalin.mailer@state.gov>
# 1   YALI Network <yalin.mailer@state.gov>
# 2   YALI Network <yalin.mailer@state.gov>
# 3   YALI Network <yalin.mailer@state.gov>
# 4   YALI Network <yalin.mailer@state.gov>
# 5   YALI Network <yalin.mailer@state.gov>
# 6   YALI Network <yalin.mailer@state.gov>
# 7   YALI Network <yalin.mailer@state.gov>
# 8   YALI Network <yalin.mailer@state.gov>
# 9   YALI Network <yalin.mailer@state.gov>
# 10  YALI Network <yalin.mailer@state.gov>
# 11  YALI Network <yalin.mailer@state.gov>
# 12  YALI Network <yalin.mailer@state.gov>
# 13  YALI Network <yalin.mailer@state.gov>
# 14  YALI Network <yalin.mailer@state.gov>
# 15  YALI Network <yalin.mailer@state.gov>
# 16  YALI Network <yalin.mailer@state.gov>
# 17  YALI Network <yalin.mailer@state.gov>
# 18  YALI Network <yalin.mailer@state.gov>
# 19  YALI Network <yalin.mailer@state.gov>
# 20  YALI Network <yalin.mailer@state.gov>
# 21  YALI Network <yalin.mailer@state.gov>
# 22  YALI Network <yalin.mailer@state.gov>
# 23  YALI Network <yalin.mailer@state.gov>
# 24  YALI Network <yalin.mailer@state.gov>
# 25  YALI Network <yalin.mailer@state.gov>
# 26  YALI Network <yalin.mailer@state.gov>
# 27  YALI Network <yalin.mailer@state.gov>
# 28  YALI Network <yalin.mailer@state.gov>
# 29  YALI Network <yalin.mailer@state.gov>
# 30  YALI Network <yalin.mailer@state.gov>
# 31  YALI Network <yalin.mailer@state.gov>
# 32  YALI Network <yalin.mailer@state.gov>
# 33  YALI Network <yalin.mailer@state.gov>
# 34  YALI Network <yalin.mailer@state.gov>
#
#                                               Subject        Date  \
# 0                   There’s a NEW YALI4Youth Workbook  2021-01-12
# 1   Be one of the first to take the NEW online course  2020-12-22
# 2                  Africa’s youth is waiting for you!  2020-12-02
# 3                              YALI4Youth Starts NOW!  2020-11-24
# 4           YALI RLC West Africa - Applications Open!  2020-10-23
# 5   Don't miss out on these financial literacy res...  2020-10-22
# 6                       YALIEntreprenuers Starts NOW!  2020-09-29
# 7   Honor the International Day of Democracy with ...  2020-09-15
# 8                    There’s a brand NEW YALI Course!  2020-09-08
# 9          It’s time to create change with YALILearns  2020-08-31
# 10  Celebrate International Youth Day with YALILearns  2020-08-12
# 11                    YALIProfessionals 2020 is Here!  2020-08-11
# 12           Celebrating YOU- the YALI 10 Generation!  2020-08-07
# 13          How will you advocate for Africa’s youth?  2020-08-05
# 14                 Happy 10 Year Anniversary of YALI!  2020-08-02
# 15          We want your thoughts on YALIServes 2020!  2020-07-24
# 16         It’s time to create change with YALILearns  2020-07-22
# 17              It’s Time to Serve Africa - Together!  2020-07-18
# 18            Don’t Miss your Chance to Serve Africa!  2020-07-14
# 19   You’re Invited: YALIServes Digital Day of Action  2020-07-07
# 20  Message from Ambassador Nagy on George Floyd's...  2020-06-16
# 21                       Let’s Serve Africa Together!  2020-06-12
# 22                Check Yourself! Join YALIChecks 2.0  2020-05-12
# 23                               Join YALIChecks 2.0!  2020-05-03
# 24  Today! YALI Network YALICHAT on Mental Health ...  2020-04-29
# 25  Okwudili, you don’t want to miss these NEW wom...  2020-04-14
# 26  Celebrate World Fact Checking Day with this Vi...  2020-04-02
# 27           Message from Ambassador Nagy on COVID-19  2020-03-31
# 28              Your Last Chance for Africa4Her 2020!  2020-03-24
# 29          Celebrate World Water Day with YALILearns  2020-03-22
# 30  Be a champion for women’s health - Join Africa...  2020-03-16
# 31                              Join Africa4Her 2020!  2020-03-08
# 32  Help Us Honor Our Environment This Month With ...  2020-03-03
# 33  Greetings from Tibor Nagy, Assistant Secretary...  2020-02-21
# 34                                A Great Year Ahead!  2020-01-01
#
#                                          Message body
# 0   Youth Mentorship Workbook No images? Click her...
# 1   New course on youth development No images? Cli...
# 2   No images? Click here <URL> Dear Okwudili, Afr...
# 3   No images? Click here <URL> Dear Okwudili, Acr...
# 4   No images? Click here <URL> Dear Okwudili, Are...
# 5   These YALIEntrepreneurs resources are here for...
# 6   Take control of your financial future No image...
# 7   No images? Click here <URL> Dear Okwudili, Hap...
# 8   No images? Click here <URL> Dear Okwudili, Res...
# 9   No images? Click here <URL> Dear Okwudili, Eac...
# 10  No images? Click here <URL> Dear Okwudili, Hap...
# 11  No images? Click here <URL> Dear Okwudili, Tod...
# 12  Join me for a special #YALI10 Facebook Live No...
# 13  No images? Click here <URL> Dear Okwudili, The...
# 14  Celebrate with two birthday presents! No image...
# 15  No images? Click here <URL> Dear YALI Network ...
# 16  No images? Click here <URL> Dear Okwudili, You...
# 17  No images? Click here <URL> Dear Okwudili, It'...
# 18  No images? Click here <URL> Dear Okwudili, The...
# 19  No images? Click here <URL> Dear Okwudili, Thi...
# 20  No images? Click here <URL> Hello YALI Network...
# 21  No images? Click here <URL> Dear Okwudili, Tod...
# 22  No images? Click here <URL> Dear Okwudili, Las...
# 23  No images? Click here <URL> Dear Okwudili, It ...
# 24  How are you coping with the #COVID19 crisis? A...
# 25  No images? Click here <URL> Dear Okwudili, Whe...
# 26  No images? Click here <URL> Dear Okwudili, Acc...
# 27  Follow the safety guidelines outlined by the C...
# 28  No images? Click here <URL> Dear Okwudili, Thi...
# 29  YALILearns : Learn to Lead No images? Click he...
# 30  Join Africa4Her : Supporting Women's Health No...
# 31  Africa4Her 2020 : Empowering Women's Health No...
# 32  YALILearns : Learn to Lead No images? Click he...
# 33  A message from the Young African Leaders Initi...
# 34  Celebrating 10 years of YALI No images? Click ...

# %%
df['Message body'][0]
# Out:
# "Youth Mentorship Workbook No images? Click here <URL> Dear Okwudili, In the past weeks, you've worked hard to learn some of the fundamentals of youth development and mentorship with our YALI4Youth Online Course. Now it's time to take your skills one step further. Today we're releasing the NEW YALI4Youth Youth Development Workbook to provide you with resources and personal exercises on some of the critical points of youth development. By completing this workbook, you'll be preparing yourself to be a successful and impactful youth mentor. So let's get started. Download and complete the new workbook today in either English, French, or Portuguese. Download the NEW Youth Development Workbook [<URL>] There's still more to come in YALI4Youth! Stay tuned to our Facebook [<URL>], Twitter [<URL>], and LinkedIn [<URL>] to see what's next. And don't forget that you can still take the YALI4Youth Pledge [<URL>], YALI4Youth Quiz [<URL>], or Online Course [<URL>] if you haven't already! Best, Sarah YALI Network Team You're receiving this email as a YALI Network member who signed up, earned a YALI Network Online Course certificate, or pledged as a part of a YALI Network initiative. Want to learn about more events in your area or causes you care about? Tell us about yourself [<URL>] and your interests here. Not Okwudili? Sign up to [<URL>] receive [<URL>] more info from the YALI Network [<URL>], straight to your inbox! Copyright © 2021 U.S. Department of State, Young African Leaders Initiative. All rights reserved. Forward <URL> Unsubscribe <URL>"
